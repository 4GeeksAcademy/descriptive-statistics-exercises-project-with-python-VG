# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# TODO
import numpy as np
import matplotlib.pyplot as plt

mu=5
sigma=0.5

s = np.random.normal(mu, sigma, 100)


count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
chi =np.random.chisquare(3,100)

plt.figure(figsize=(8, 5))
plt.hist(chi, bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title('Distribución Chi-cuadrado con 3 grados de libertad')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
import statistics as stats
from scipy.stats import skew
from scipy.stats import kurtosis
import pandas as pd

df = pd.DataFrame(s,columns=['Normal'])
print(df.describe())
df_chi=pd.DataFrame(chi, columns=["Chi-square"])
print(df_chi.describe())
# Out:
#            Normal
# count  100.000000
# mean     5.056316
# std      0.497981
# min      3.817868
# 25%      4.693402
# 50%      5.058132
# 75%      5.445039
# max      6.236342
#        Chi-square
# count  100.000000
# mean     3.314765
# std      2.746084
# min      0.023785
# 25%      1.583189
# 50%      2.610381
# 75%      4.189468
# max     15.250881

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# TODO

data = [4, 2, 5, 8, 6]
d=pd.array(data)

mean=d.mean()
desv_stand=((sum((d-mean)**2))/len(d))**(1/2)
print(f"La desviación estandard de la lista data es de {desv_stand}.")
# Out:
# La desviación estandard de la lista data es de 2.0
